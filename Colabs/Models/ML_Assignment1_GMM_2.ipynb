# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowri-Rk/Machine-Learning/blob/master/Colabs/Models/ML_Assignment1_GMM_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from pandas import DataFrame 
from sklearn import datasets 
from sklearn.mixture import GaussianMixture

# %%
from google.colab import drive
drive.mount('/content/gdrive')
ds = pd.read_csv("/content/gdrive/My Drive/MLSpring2020/datatribe-nutritionbasediseaseprediction/Assignments/Assignment 1/Gowri/demographic.csv")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
ds.head(10)
# Out:
#     SEQN  SDDSRVYR  RIDSTATR  ...  Unnamed: 57  Unnamed: 58  Unnamed: 59
# 0  73557         8         2  ...
# 1  73558         8         2  ...          NaN          NaN          NaN
# 2  73559         8         2  ...          NaN          NaN          NaN
# 3  73560         8         2  ...          NaN          NaN          NaN
# 4  73561         8         2  ...          NaN          NaN          NaN
# 5  73562         8         2  ...          NaN          NaN          NaN
# 6  73563         8         2  ...          NaN          NaN          NaN
# 7  73564         8         2  ...          NaN          NaN          NaN
# 8  73565         8         1  ...          NaN          NaN          NaN
# 9  73566         8         2  ...          NaN          NaN          NaN
#
# [10 rows x 60 columns]

# %%
X = ds.dropna(axis='columns')

# %%
#plot the data
plt.scatter(ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-ba277040b9c3> in <module>()
# ----> 1 plt.scatter(ds)
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
gmm = GaussianMixture(n_components = 3)

# %%
gmm.fit(X)
# Out:
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=3, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Assign a label to each sample 
labels = gmm.predict(X) 
X['labels']= labels 
d0 = X[X['labels']== 0] 
d1 = X[X['labels']== 1] 
d2 = X[X['labels']== 2]

# %%
d0
# Out:
#         SEQN  SDDSRVYR  RIDSTATR  ...  SDMVPSU  SDMVSTRA  labels
# 8      73565         8         1  ...        2       106       0
# 12     73569         8         1  ...        1       110       0
# 20     73577         8         2  ...        2       118       0
# 68     73625         8         1  ...        1       118       0
# 77     73634         8         1  ...        2       113       0
# ...      ...       ...       ...  ...      ...       ...     ...
# 10049  83606         8         2  ...        2       104       0
# 10060  83617         8         2  ...        2       118       0
# 10078  83635         8         1  ...        1       113       0
# 10095  83652         8         1  ...        2       106       0
# 10100  83657         8         1  ...        2       115       0
#
# [700 rows x 22 columns]

# %%
d1
# Out:
#         SEQN  SDDSRVYR  RIDSTATR  ...  SDMVPSU  SDMVSTRA  labels
# 1      73558         8         2  ...        1       108       1
# 2      73559         8         2  ...        1       109       1
# 3      73560         8         2  ...        2       109       1
# 4      73561         8         2  ...        2       116       1
# 6      73563         8         2  ...        1       105       1
# ...      ...       ...       ...  ...      ...       ...     ...
# 10157  83714         8         2  ...        1       114       1
# 10158  83715         8         2  ...        2       116       1
# 10159  83716         8         2  ...        1       116       1
# 10164  83721         8         2  ...        1       112       1
# 10167  83724         8         2  ...        1       117       1
#
# [3473 rows x 22 columns]

# %%
d2
# Out:
#         SEQN  SDDSRVYR  RIDSTATR  ...  SDMVPSU  SDMVSTRA  labels
# 0      73557         8         2  ...        1       112       2
# 5      73562         8         2  ...        1       111       2
# 13     73570         8         2  ...        2       115       2
# 15     73572         8         2  ...        2       111       2
# 16     73573         8         2  ...        2       106       2
# ...      ...       ...       ...  ...      ...       ...     ...
# 10170  83727         8         2  ...        1       104       2
# 10171  83728         8         2  ...        1       107       2
# 10172  83729         8         2  ...        1       104       2
# 10173  83730         8         2  ...        2       109       2
# 10174  83731         8         2  ...        2       106       2
#
# [6002 rows x 22 columns]

# %%
# print the converged log-likelihood value 
print(gmm.lower_bound_)
# Out:
# -27.613075360247983

# %%
# print the number of iterations needed 
# for the log-likelihood value to converge 
print(gmm.n_iter_)
# Out:
# 9

# %%
d0['SEQN']
# Out:
# 8        73565
# 12       73569
# 20       73577
# 68       73625
# 77       73634
#          ...
# 10049    83606
# 10060    83617
# 10078    83635
# 10095    83652
# 10100    83657
# Name: SEQN, Length: 700, dtype: int64

# %%
# plot three clusters in same plot 
plt.scatter(d0['RIDAGEYR'], d0['DMDHRAGE'], c ='r') 
plt.scatter(d1['RIDAGEYR'], d1['DMDHRAGE'], c ='yellow') 
plt.scatter(d2['RIDAGEYR'], d2['DMDHRAGE'], c ='g')
